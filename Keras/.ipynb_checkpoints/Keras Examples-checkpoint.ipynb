# %%
import pandas as pd
import keras
import numpy as np
import pydot

# %% [markdown]
# ## 1 Defining a Keras Model

# %% [markdown]
# ### 1.1 Single Input

# %% [markdown]
# The first step in creating a neural network model is to define the Input layer. This layer takes in raw data, usually in the form of numpy arrays. The shape of the Input layer defines how many variables your neural network will use. For example, if the input data has 10 columns, you define an Input layer with a shape of (10,).

# %%
input_tensor = keras.Input(shape=(1,0))
print(input_tensor)
# Out:
# Tensor("input_1:0", shape=(?, 1, 0), dtype=float32)

# %% [markdown]
# ### 1.2 Single Output

# %% [markdown]
# Once you have an Input layer, the next step is to add a Dense layer.
#
# Dense layers learn a weight matrix, where the first dimension of the matrix is the dimension of the input data, and the second dimension is the dimension of the output data. Recall that your Input layer has a shape of 1. In this case, your output layer will also have a shape of 1. This means that the Dense layer will learn a 1x1 weight matrix.

# %%
output_layer = keras.layers.Dense(1)
print(output_layer)
# Out:
# <keras.layers.core.Dense object at 0x00000239DBB00940>

# %% [markdown]
# #### Note that layers are functions and not tensors. Layers are used to construct a deep learning model and tensors are used to define the dataflow trought the model.

# %% [markdown]
# ### 1.3 Connecting inputs to outputs

# %% [markdown]
# Output layers are simply Dense layers! Output layers are used to reduce the dimension of the inputs to the dimension of the outputs. You'll learn more about output dimensions in chapter 4, but for now, you'll always use a single output in your neural networks, which is equivalent to Dense(1) or a dense layer with a single unit.

# %% [markdown]
# ![img1.png](attachment:img1.png)

# %%
from keras.layers import Input, Dense
input_tensor = Input(shape=(1,))
output_layer = Dense(1)
output_tensor = output_layer(input_tensor)
print(output_tensor)
# Out:
# Tensor("dense_4/BiasAdd:0", shape=(?, 1), dtype=float32)

# %% [markdown]
# #### The cell above is equivalent to:

# %%
input_tensor = Input(shape=(1,))
output_tensor = Dense(1)(input_tensor)

# %% [markdown]
# #### The final output of the model is also a Tensor.

# %% [markdown]
# ### 1.4 Creating a Model

# %% [markdown]
# Once you've defined an input layer and an output layer, you can build a Keras model. The model object is how you tell Keras where the model starts and stops: where data comes in and where predictions come out.

# %% [markdown]
# ![img2.png](attachment:img2.png)

# %%
from keras.models import Model
model = Model(input_tensor,output_tensor)

# %% [markdown]
# ### 1.5 Compile a Model

# %% [markdown]
# The final step in creating a model is compiling it. Now that you've created a model, you have to compile it before you can fit it to data. This finalizes your model, freezes all its settings, and prepares it to meet some data!
#
# During compilation, you specify the optimizer to use for fitting the model to the data, and a loss function. 'adam' is a good default optimizer to use, and will generally work well. Loss function depends on the problem at hand. Mean squared error is a common loss function and will optimize for predicting the mean, as is done in least squares regression.
#
# Mean absolute error optimizes for the median and is used in quantile regression. For this dataset, 'mean_absolute_error' works pretty well, so use it as your loss function.

# %%
model.compile(optimizer='adam', loss='mae')

# %% [markdown]
# ### 1.6 Visualize a Model

# %% [markdown]
# Onde the model is compiled it's possible to take look a the. To do this we can look at the model summary, as well as its plot.
#
# The summary will tell you the names of the layers, as well as how many units they have and how many parameters are in the model.
#
# The plot will show how the layers connect to each other.

# %%
from keras.utils import plot_model
import matplotlib.pyplot as plt

# Summarize the model
model.summary()

# Plot the model
plot_model(model, to_file='model.png')

# Display the image
data = plt.imread('model.png')
plt.imshow(data)
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Importing csv with data

# %%
games_season = pd.read_csv('datasets/Big_Dance.csv')
games_season.head()
# Out:
#    Year  Round  Region Number Region Name  Seed  Score        Team  \
# 0  1985      1              1        West     1     83    St Johns
# 1  1985      1              1        West     2     81         VCU
# 2  1985      1              1        West     3     65    NC State
# 3  1985      1              1        West     4     85        UNLV
# 4  1985      1              1        West     5     58  Washington
#
#          Team.1  Score.1  Seed.1
# 0      Southern       59      16
# 1      Marshall       65      15
# 2        Nevada       56      14
# 3  San Diego St       80      13
# 4      Kentucky       65      12

# %% [markdown]
# ### Preparing data for the SISO model created above

# %%
games_season['score_diff']=games_season['Score'] - games_season['Score.1']
games_season['seed_diff']=games_season['Seed'] - games_season['Seed.1']
games_season.head()
# Out:
#    Year  Round  Region Number Region Name  Seed  Score        Team  \
# 0  1985      1              1        West     1     83    St Johns
# 1  1985      1              1        West     2     81         VCU
# 2  1985      1              1        West     3     65    NC State
# 3  1985      1              1        West     4     85        UNLV
# 4  1985      1              1        West     5     58  Washington
#
#          Team.1  Score.1  Seed.1  score_diff  seed_diff
# 0      Southern       59      16          24        -15
# 1      Marshall       65      15          16        -13
# 2        Nevada       56      14           9        -11
# 3  San Diego St       80      13           5         -9
# 4      Kentucky       65      12          -7         -7

# %%
games_season.hist(column="seed_diff")
games_season.hist(column="score_diff")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000239DD3549E8>]],
#       dtype=object)

# %% [markdown]
# ### Spliting Data into training and testing sets

# %%
games_season_training = games_season.iloc[:2000]
games_season_testing = games_season.iloc[2000:]

# %%
games_season_training.head()
# Out:
#    Year  Round  Region Number Region Name  Seed  Score        Team  \
# 0  1985      1              1        West     1     83    St Johns
# 1  1985      1              1        West     2     81         VCU
# 2  1985      1              1        West     3     65    NC State
# 3  1985      1              1        West     4     85        UNLV
# 4  1985      1              1        West     5     58  Washington
#
#          Team.1  Score.1  Seed.1  score_diff  seed_diff
# 0      Southern       59      16          24        -15
# 1      Marshall       65      15          16        -13
# 2        Nevada       56      14           9        -11
# 3  San Diego St       80      13           5         -9
# 4      Kentucky       65      12          -7         -7

# %%
games_season_testing
# Out:
#       Year  Round  Region Number   Region Name  Seed  Score            Team  \
# 2000  2016      2              4       Midwest     4     78         Iowa St
# 2001  2016      3              1         South     1     79          Kansas
# 2002  2016      3              1         South     2     92       Villanova
# 2003  2016      3              2          West     1     82          Oregon
# 2004  2016      3              2          West     2     77        Oklahoma
# 2005  2016      3              3          East     1    101  North Carolina
# 2006  2016      3              3          East     7     56       Wisconsin
# 2007  2016      3              4       Midwest     1     84        Virginia
# 2008  2016      3              4       Midwest    10     63        Syracuse
# 2009  2016      4              1         South     1     59          Kansas
# 2010  2016      4              2          West     1     68          Oregon
# 2011  2016      4              3          East     1     88  North Carolina
# 2012  2016      4              4       Midwest     1     62        Virginia
# 2013  2016      5              1    Final Four     2     95       Villanova
# 2014  2016      5              2    Final Four     1     83  North Carolina
# 2015  2016      6              1  Championship     2     77       Villanova
# 2016  2017      1              1          East     1     76       Villanova
# 2017  2017      1              1          East     2     87            Duke
# 2018  2017      1              1          East     3     91          Baylor
# 2019  2017      1              1          East     4     80         Florida
# 2020  2017      1              1          East     5     76        Virginia
# 2021  2017      1              1          East     6     65             SMU
# 2022  2017      1              1          East     7     93  South Carolina
# 2023  2017      1              1          East     8     84       Wisconsin
# 2024  2017      1              2          West     1     66         Gonzaga
# 2025  2017      1              2          West     2    100         Arizona
# 2026  2017      1              2          West     3     86      Florida St
# 2027  2017      1              2          West     4     86   West Virginia
# 2028  2017      1              2          West     5     60      Notre Dame
# 2029  2017      1              2          West     6     65        Maryland
# ...    ...    ...            ...           ...   ...    ...             ...
# 2112  2018      2              1         South     2     73      Cincinnati
# 2113  2018      2              1         South     3     62       Tennessee
# 2114  2018      2              1         South    13     75         Buffalo
# 2115  2018      2              2          West     1     70          Xavier
# 2116  2018      2              2          West     2     65  North Carolina
# 2117  2018      2              2          West     3     64        Michigan
# 2118  2018      2              2          West     4     90         Gonzaga
# 2119  2018      2              3          East     1     81       Villanova
# 2120  2018      2              3          East     2     76          Purdue
# 2121  2018      2              3          East     3     69      Texas Tech
# 2122  2018      2              3          East    13     71        Marshall
# 2123  2018      2              4       Midwest     1     83          Kansas
# 2124  2018      2              4       Midwest     2     87            Duke
# 2125  2018      2              4       Midwest     3     53     Michigan St
# 2126  2018      2              4       Midwest     4     53          Auburn
# 2127  2018      3              1         South     9     61       Kansas St
# 2128  2018      3              1         South     7     68          Nevada
# 2129  2018      3              2          West     9     75      Florida St
# 2130  2018      3              2          West     7     72       Texas A&M
# 2131  2018      3              3          East     1     90       Villanova
# 2132  2018      3              3          East     2     65          Purdue
# 2133  2018      3              4       Midwest     1     80          Kansas
# 2134  2018      3              4       Midwest     2     69            Duke
# 2135  2018      4              1         South     9     62       Kansas St
# 2136  2018      4              2          West     9     54      Florida St
# 2137  2018      4              3          East     1     71       Villanova
# 2138  2018      4              4       Midwest     1     85          Kansas
# 2139  2018      5              1    Final Four    11     57  Loyola Chicago
# 2140  2018      5              2    Final Four     1     95       Villanova
# 2141  2018      6              1  Championship     3     62        Michigan
#
#                     Team.1  Score.1  Seed.1  score_diff  seed_diff  prediction
# 2000  Arkansas Little Rock       61      12          17         -8   11.807898
# 2001              Maryland       63       5          16         -4    5.894979
# 2002                 Miami       69       3          23         -1    1.460290
# 2003                  Duke       68       4          14         -3    4.416750
# 2004             Texas A&M       63       3          14         -1    1.460290
# 2005               Indiana       86       5          15         -4    5.894979
# 2006            Notre Dame       61       6          -5          1   -1.496169
# 2007               Iowa St       71       4          13         -3    4.416750
# 2008               Gonzaga       60      11           3         -1    1.460290
# 2009             Villanova       64       2          -5         -1    1.460290
# 2010              Oklahoma       80       2         -12         -1    1.460290
# 2011            Notre Dame       74       6          14         -5    7.373209
# 2012              Syracuse       68      10          -6         -9   13.286127
# 2013              Oklahoma       51       2          44          0   -0.017939
# 2014              Syracuse       66      10          17         -9   13.286127
# 2015        North Carolina       74       1           3          1   -1.496169
# 2016        Mount St Marys       56      16          20        -15   22.155506
# 2017                  Troy       65      15          22        -13   19.199047
# 2018         New Mexico St       73      14          18        -11   16.242588
# 2019     East Tennessee St       65      13          15         -9   13.286127
# 2020        UNC Wilmington       71      12           5         -7   10.329668
# 2021                   USC       66      11          -1         -5    7.373209
# 2022             Marquette       73      10          20         -3    4.416750
# 2023         Virginia Tech       74       9          10         -1    1.460290
# 2024       South Dakota St       46      16          20        -15   22.155506
# 2025          North Dakota       82      15          18        -13   19.199047
# 2026    Florida Gulf Coast       80      14           6        -11   16.242588
# 2027              Bucknell       80      13           6         -9   13.286127
# 2028             Princeton       58      12           2         -7   10.329668
# 2029                Xavier       76      11         -11         -5    7.373209
# ...                    ...      ...     ...         ...        ...         ...
# 2112                Nevada       75       7          -2         -5    7.373209
# 2113        Loyola Chicago       63      11          -1         -8   11.807898
# 2114              Kentucky       95       5         -20          8  -11.843777
# 2115            Florida St       75       9          -5         -8   11.807898
# 2116             Texas A&M       86       7         -21         -5    7.373209
# 2117               Houston       63       6           1         -3    4.416750
# 2118               Ohio St       84       5           6         -1    1.460290
# 2119               Alabama       58       9          23         -8   11.807898
# 2120                Butler       73      10           3         -8   11.807898
# 2121               Florida       66       6           3         -3    4.416750
# 2122         West Virginia       94       5         -23          8  -11.843777
# 2123            Seton Hall       79       8           4         -7   10.329668
# 2124          Rhode Island       62       7          25         -5    7.373209
# 2125              Syracuse       55      11          -2         -8   11.807898
# 2126               Clemson       84       5         -31         -1    1.460290
# 2127              Kentucky       58       5           3          4   -5.930858
# 2128        Loyola Chicago       69      11          -1         -4    5.894979
# 2129               Gonzaga       60       4          15          5   -7.409087
# 2130              Michigan       99       3         -27          4   -5.930858
# 2131         West Virginia       78       5          12         -4    5.894979
# 2132            Texas Tech       78       3         -13         -1    1.460290
# 2133               Clemson       76       5           4         -4    5.894979
# 2134              Syracuse       65      11           4         -9   13.286127
# 2135        Loyola Chicago       78      11         -16         -2    2.938520
# 2136              Michigan       58       3          -4          6   -8.887318
# 2137            Texas Tech       59       3          12         -2    2.938520
# 2138                  Duke       81       2           4         -1    1.460290
# 2139              Michigan       69       3         -12          8  -11.843777
# 2140                Kansas       79       1          16          0   -0.017939
# 2141             Villanova       79       1         -17          2   -2.974399
#
# [142 rows x 13 columns]

# %%
print("For Training Data:")
print("Maximum seed difference: ",games_season_training['seed_diff'].max())
print("Minimun seed difference: ",games_season_training['seed_diff'].min())
print("Maximum score difference: ",games_season_training['score_diff'].max())
print("Minimun score difference: ",games_season_training['score_diff'].min())
print("\nFor Testing Data:")
print("Maximum seed difference: ",games_season_testing['seed_diff'].max())
print("Minimun seed difference: ",games_season_testing['seed_diff'].min())
print("Maximum score difference: ",games_season_testing['score_diff'].max())
print("Minimun score difference: ",games_season_testing['score_diff'].min())
# Out:
# For Training Data:
# Maximum seed difference:  12
# Minimun seed difference:  -15
# Maximum score difference:  58
# Minimun score difference:  -43
#
# For Testing Data:
# Maximum seed difference:  8
# Minimun seed difference:  -15
# Maximum score difference:  44
# Minimun score difference:  -31

# %% [markdown]
# ### Basketball Data
#
#     Input:
#         * Seed difference - one number: -15 to +15
#         * Seed range from 1-16
#         * Highest difference is 12
#         * Lowest difference is -15
#     Output:
#         * Score difference - one number: -43 to +58

# %% [markdown]
# ## Fitting the Model

# %%
history = model.fit(games_season_training['seed_diff'],
          games_season_training['score_diff'],
          batch_size=64,
          epochs=10,
          validation_split=0.20,
          verbose=True)
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/10
# 1600/1600 [==============================] - 0s 9us/step - loss: 9.1641 - val_loss: 9.4170
# Epoch 2/10
# 1600/1600 [==============================] - 0s 8us/step - loss: 9.1526 - val_loss: 9.3967
# Epoch 3/10
# 1600/1600 [==============================] - 0s 9us/step - loss: 9.1433 - val_loss: 9.3768
# Epoch 4/10
# 1600/1600 [==============================] - 0s 11us/step - loss: 9.1340 - val_loss: 9.3614
# Epoch 5/10
# 1600/1600 [==============================] - 0s 10us/step - loss: 9.1266 - val_loss: 9.3487
# Epoch 6/10
# 1600/1600 [==============================] - 0s 12us/step - loss: 9.1209 - val_loss: 9.3370
# Epoch 7/10
# 1600/1600 [==============================] - 0s 9us/step - loss: 9.1156 - val_loss: 9.3258
# Epoch 8/10
# 1600/1600 [==============================] - 0s 12us/step - loss: 9.1119 - val_loss: 9.3190
# Epoch 9/10
# 1600/1600 [==============================] - 0s 11us/step - loss: 9.1104 - val_loss: 9.3143
# Epoch 10/10
# 1600/1600 [==============================] - 0s 10us/step - loss: 9.1092 - val_loss: 9.3081

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Evaluate the Model

# %%
model.evaluate(games_season_testing['seed_diff'],
          games_season_testing['score_diff'])
# Out:
# 142/142 [==============================] - 0s 21us/step
# 9.363657226025218

# %%
prediction = model.predict(games_season_testing['seed_diff'])
#results_dataset = pd.DataFrame({'Prediction':prediction,'Real Outcome':games_season_testing['score_diff']})

# %%
results_datframe = pd.DataFrame({'Prediction Results':prediction[:,0]})
#results_dataset.join(games_season_testing['score_diff'])

# %%
comparison = games_season_testing.filter(['score_diff'], axis=1)
comparison = comparison.reset_index(drop=True)

# %%
results_datframe.join(comparison, lsuffix='_caller', rsuffix='_other')
# Out:
#      Prediction Results  score_diff
# 0             10.479553          17
# 1              5.163121          16
# 2              1.175796          23
# 3              3.834013          14
# 4              1.175796          14
# 5              5.163121          15
# 6             -1.482420          -5
# 7              3.834013          13
# 8              1.175796           3
# 9              1.175796          -5
# 10             1.175796         -12
# 11             6.492229          14
# 12            11.808661          -6
# 13            -0.153312          44
# 14            11.808661          17
# 15            -1.482420           3
# 16            19.783310          20
# 17            17.125093          22
# 18            14.466878          18
# 19            11.808661          15
# 20             9.150445           5
# 21             6.492229          -1
# 22             3.834013          20
# 23             1.175796          10
# 24            19.783310          20
# 25            17.125093          18
# 26            14.466878           6
# 27            11.808661           6
# 28             9.150445           2
# 29             6.492229         -11
# ..                  ...         ...
# 112            6.492229          -2
# 113           10.479553          -1
# 114          -10.786177         -20
# 115           10.479553          -5
# 116            6.492229         -21
# 117            3.834013           1
# 118            1.175796           6
# 119           10.479553          23
# 120           10.479553           3
# 121            3.834013           3
# 122          -10.786177         -23
# 123            9.150445           4
# 124            6.492229          25
# 125           10.479553          -2
# 126            1.175796         -31
# 127           -5.469744           3
# 128            5.163121          -1
# 129           -6.798852          15
# 130           -5.469744         -27
# 131            5.163121          12
# 132            1.175796         -13
# 133            5.163121           4
# 134           11.808661           4
# 135            2.504905         -16
# 136           -8.127960          -4
# 137            2.504905          12
# 138            1.175796           4
# 139          -10.786177         -12
# 140           -0.153312          16
# 141           -2.811528         -17
#
# [142 rows x 2 columns]
